# %%
import pandas as pd

events = pd.read_csv("../data/events/oil_market_events.csv")
events["date"] = pd.to_datetime(events["date"])

print(events)
# Out:
#          date                          event      category
# 0  2001-09-11         9/11 Terrorist Attacks  Geopolitical
# 1  2003-03-20                Iraq War Begins      Conflict
# 2  2008-09-15        Global Financial Crisis      Economic
# 3  2010-04-20    Deepwater Horizon Oil Spill      Industry
# 4  2011-02-15             Arab Spring Begins  Geopolitical
# 5  2014-11-27    OPEC Refuses Production Cut          OPEC
# 6  2016-11-30            OPEC Production Cut          OPEC
# 7  2018-05-08           US Sanctions on Iran     Sanctions
# 8  2020-03-11     COVID-19 Pandemic Declared  Global Shock
# 9  2020-04-12  OPEC+ Historic Production Cut          OPEC
# 10 2022-02-24         Russia Invades Ukraine      Conflict
